# %%
df = (
spark.sql("CREATE	CATALOG	IF	NOT	EXISTS	fintech_fraud_risk"),
spark.sql("CREATE	SCHEMA	IF	NOT	EXISTS	fintech_fraud_risk.bronze"),
spark.sql("CREATE	SCHEMA	IF	NOT	EXISTS	fintech_fraud_risk.silver"),
spark.sql("CREATE	SCHEMA	IF	NOT	EXISTS	fintech_fraud_risk.gold"),
spark.sql("CREATE	VOLUME	IF	NOT	EXISTS	fintech_fraud_risk.bronze.vol_bronze")

)
